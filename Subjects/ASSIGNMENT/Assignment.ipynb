# %%
# 🐍 <span style="color:purple">Experiment 1: Python Installation and Starting with Python</span>

![Python Logo](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)

## 🌟 <span style="color:teal">Welcome to the World of Python!</span>

Python is a beginner-friendly, powerful, and versatile programming language widely used in **Web Development, Artificial Intelligence, Data Science, Automation, and Cyber Security**.

> 💡 **Fun Fact:** Python was created by **Guido van Rossum** in 1991 and is loved for its simple syntax.

---
# Out:
#   Cell In[1], line 9
#     > 💡 **Fun Fact:** Python was created by **Guido van Rossum** in 1991 and is loved for its simple syntax.
#       ^
# SyntaxError: invalid character '💡' (U+1F4A1)

# %% [markdown]
# # 🐍 <span style="color:purple">Experiment 1: Python Installation and Starting with Python</span>
#
# ![Python Logo](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
#
# ## 🌟 <span style="color:teal">Welcome to the World of Python!</span>
#
# Python is a beginner-friendly, powerful, and versatile programming language widely used in **Web Development, Artificial Intelligence, Data Science, Automation, and Cyber Security**.
#
# > 💡 **Fun Fact:** Python was created by **Guido van Rossum** in 1991 and is loved for its simple syntax.
#
# ---

# %% [markdown]
# # 🟣 Experiment 1: Python Installation and Basics
#
# ## 🌟 Welcome to Python Programming
#
# Python is one of the world's most popular programming languages because of its **simple syntax**, **readability**, and **versatility**. This experiment introduces the basic concepts of Python programming and verifies the successful installation of the Python environment.
#
# ---

# %% [markdown]
# # **ASSIGNMENT**
#
# ## **Name:- Shivani**
# ## **Student ID:- 590035140**
# ## **Program:- MTech.**

# %% [markdown]
# ## Experiment 1: Python Installation and Starting with Python

# %% [markdown]
# ## Experiment 1: Python Installation and Starting with Python
#
# **This notebook contains neatly formatted questions, explanations, and Python solutions for lab practice.**

# %% [markdown]
# ### **Question 1**
#
# Install Python and understand the difference between scripting mode and interactive mode in IDLE.
#
# **What is interactive programming in python?**
#
#     When we can run a programing directly from terminal , and the output is instant. We dont need a helper command to run the script.

# %%
a = 30
b = 20
print("What is the product of a and b")
print(a*b)

# %% [markdown]
# **What is script programming in python?**
#
#     When we submit the script to the compiler using a helper command. In the case of python the terminal command is "python - file name"

# %%
# !python product1.py

# %%
import sys

print("Python is installed.")
print("Version:", sys.version)

# %% [markdown]
# ### **Question 2**
#
# Write Python programs to print strings in the given manner.

# %%
# 2(a)
print("Hello Everyone !!!")

# 2(b)
print("Hello")
print("World")

# 2(c)
print("Hello\nWorld")

# 2(d)
print("Rohit's date of birth is 12\05\1999")
# Out:
# Hello Everyone !!!
# Hello
# World
# Hello
# World
# Rohit's date of birth is 12999
