# %% [markdown]
# ***
# ***
# ## CHAPTER-2
# ### PRACTICE SET

# %%
print(name[:10])

print(name[3 :10])
# Out:
# youtube
# tube

# %% [markdown]
# ***
# ***Write a python program to add two numbers***

# %%
a=26
b=78
c=a+b
print(c)
# Out:
# 104

# %% [markdown]
# ***
# ***Write a python program to find remainder when a number is divided by another number z***

# %%
n1=int(input("enter the number to be divided"))
n2=int(input("enter the number to divide by"))

print(n1%n2)
print((f"reminder of {n1} divide by {n2} is {n1%n2}"))
# Out:
# 4
# reminder of 9 divide by 5 is 4

# %% [markdown]
# ***
# ***check the type of variable assigned using input() function***

# %%
n= int(input("enter the  input"))
print(type(n))

u=input("enter the  input")
print(type(u))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ***
# ***Use comparison operator to find out whether a given variable a is greater than"b" or not .take a=34 and b=80***

# %%
a=34
b=80
print(a<b)
print(b<a)
# Out:
# True
# False

# %% [markdown]
# ***
# ***write a python program to fing the average of two numbers entered by the user***

# %%
a= int(input("enter the value of a"))
b= int(input("enter the value of b"))

c=(a+b)/2
print(c)
print(type(c))
print(int(c))
# Out:
# 5

# %% [markdown]
# ***
# ***write a python program to calculate the square of a number entered by the user***

# %%
n1= int(input("enter the value of n1"))
n1*=n1
print(n1)
# Out:
# 25

# %% [markdown]
# ***
# ***
#
# ## CHAPTER-7
# ### PRACTICE SET

# %% [markdown]
# ****
# ***Write a program to print multiplication table of a given number using for loop***

# %%
def table(num):
    for i in range(1,11):
        print(num, "x", i, "=", num*i)

num=int(input("enter a number:"))
table(num)
# Out:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %% [markdown]
# ****
# ***Write a program to greet all the person names stored in a list 'l' and which starts with s.***
#
# **l=["harry","soham","sachin","rahul"]**

# %%
l=["harry","soham","sachin","rahul"]  
for name in l:
    if(name[0]=="s"):
    # if (name.startswith("s")):
        print("greet",name)
# Out:
# greet soham
# greet sachin

# %% [markdown]
# ****
# ***Write a program to print multiplication table of a given number using while loop***

# %%
def table(num):
    i=1
    while(i<=10):
        print(num, "x", i, "=", num*i)
        i+=1

num=int(input("enter a number:"))
table(num)
# Out:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %% [markdown]
# ****
# ***Write a program to find whether a given number is prime or not***

# %%
def prime(num):
    for i in range(2,num):
        if(num%i==0):
            print(num,"is not a prime number")
            break
    else:
        print(num,"is a prime number")

n=int(input("enter the number"))
prime(n)
# Out:
# 7 is a prime number
# 7 is a prime number
# 7 is a prime number
# 7 is a prime number
# 7 is a prime number

# %% [markdown]
# ****
# ***Write a program to find the sum of fisrt n natural numbers using while loop***

# %%
num= int(input("enter the number" ))
i=0
sum=0
while(i<=num):
    sum+=i
    i+=1
print("the sum of first",num,"numbers is",sum)
# Out:
# the sum of first 6 numbers is 15

# %% [markdown]
# ****
# ***Write a program to calculate the factorial of a given numbers using if & else***

# %%
def factorial(num):
    if(num==0 or num==1):
        return 1
    else:
        return(num*factorial(num-1))

num= int (input("enter the number for factorial"))
factorial(num)
# Out:
# 24

# %% [markdown]
# ****
# ***Write a program to calculate the factorial of a given numbers using for loop***

# %%
def factorial(num):
    fact=1
    for i in range(1,num+1):
        fact=fact*i
    print(fact)
    
num= int (input("enter the number for factorial"))
factorial(num)
# Out:
# 6
